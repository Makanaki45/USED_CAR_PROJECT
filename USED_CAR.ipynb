# %%
import pandas as pd

# %%
car = pd.read_csv('used_cars_UK.csv')

# %%
car
# Out:
#       Unnamed: 0           title  Price  Mileage(miles)  Registration_Year  \
# 0              0     SKODA Fabia   6900           70189               2016
# 1              1  Vauxhall Corsa   1495           88585               2008
# 2              2     Hyundai i30    949          137000               2011
# 3              3      MINI Hatch   2395           96731               2010
# 4              4  Vauxhall Corsa   1000           85000               2013
# ...          ...             ...    ...             ...                ...
# 3680        4723  Renault Megane   1395           76202               2006
# 3681        4724         Audi A4   6990          119000               2012
# 3682        4725    BMW 3 Series   3995          139000               2013
# 3683        4726    Honda Accord   1390          179190               2007
# 3684        4727  Vauxhall Corsa   2000           82160               2013
#
# ...

# %%
car.head()
# Out:
#    Unnamed: 0           title  Price  Mileage(miles)  Registration_Year  \
# 0           0     SKODA Fabia   6900           70189               2016
# 1           1  Vauxhall Corsa   1495           88585               2008
# 2           2     Hyundai i30    949          137000               2011
# 3           3      MINI Hatch   2395           96731               2010
# 4           4  Vauxhall Corsa   1000           85000               2013
#
#    Previous Owners Fuel type  Body type Engine Gearbox  Doors  Seats  \
# 0              3.0    Diesel  Hatchback   1.4L  Manual    5.0    5.0
# 1              4.0    Petrol  Hatchback   1.2L  Manual    3.0    5.0
# 2              NaN    Petrol  Hatchback   1.4L  Manual    5.0    5.0
# 3              5.0    Petrol  Hatchback   1.4L  Manual    3.0    4.0
# 4              NaN    Diesel  Hatchback   1.3L  Manual    5.0    5.0
#
#   Emission Class Service history
# 0         Euro 6             NaN
# 1         Euro 4            Full
# ...

# %%
car.tail()
# Out:
#       Unnamed: 0           title  Price  Mileage(miles)  Registration_Year  \
# 3680        4723  Renault Megane   1395           76202               2006
# 3681        4724         Audi A4   6990          119000               2012
# 3682        4725    BMW 3 Series   3995          139000               2013
# 3683        4726    Honda Accord   1390          179190               2007
# 3684        4727  Vauxhall Corsa   2000           82160               2013
#
#       Previous Owners Fuel type  Body type Engine Gearbox  Doors  Seats  \
# 3680              4.0    Petrol  Hatchback   1.6L  Manual    5.0    5.0
# 3681              NaN    Petrol     Saloon   2.0L  Manual    4.0    5.0
# 3682              NaN    Diesel     Saloon   2.0L  Manual    4.0    5.0
# 3683              NaN    Diesel     Estate   2.2L  Manual    5.0    5.0
# 3684              7.0    Petrol  Hatchback   1.2L  Manual    5.0    5.0
#
#      Emission Class Service history
# 3680         Euro 4             NaN
# ...

# %%
car.shape
# Out:
# (3685, 14)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3685 entries, 0 to 3684
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         3685 non-null   int64
#  1   title              3685 non-null   object
#  2   Price              3685 non-null   int64
#  3   Mileage(miles)     3685 non-null   int64
#  4   Registration_Year  3685 non-null   int64
#  5   Previous Owners    2276 non-null   float64
#  6   Fuel type          3685 non-null   object
#  7   Body type          3685 non-null   object
#  8   Engine             3640 non-null   object
#  9   Gearbox            3685 non-null   object
#  10  Doors              3660 non-null   float64
#  11  Seats              3650 non-null   float64
#  12  Emission Class     3598 non-null   object
#  13  Service history    540 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 403.2+ KB

# %%
car.describe()
# Out:
#         Unnamed: 0         Price  Mileage(miles)  Registration_Year  \
# count  3685.000000   3685.000000    3.685000e+03        3685.000000
# mean   2314.770963   5787.145726    8.132816e+04        2011.835007
# std    1415.821308   4480.810572    3.942083e+04           5.092566
# min       0.000000    400.000000    1.000000e+00        1953.000000
# 25%    1059.000000   2490.000000    5.698400e+04        2008.000000
# 50%    2279.000000   4000.000000    8.000000e+04        2012.000000
# 75%    3593.000000   7995.000000    1.030000e+05        2015.000000
# max    4727.000000  33900.000000    1.110100e+06        2023.000000
#
#        Previous Owners        Doors        Seats
# count      2276.000000  3660.000000  3650.000000
# mean          2.807557     4.321038     4.900274
# std           1.546028     0.986902     0.577200
# min           1.000000     2.000000     2.000000
# 25%           2.000000     3.000000     5.000000
# 50%           3.000000     5.000000     5.000000
# ...

# %%
#Distinct Registration_Year
car['Registration_Year'].unique()
# Out:
# array([2016, 2008, 2011, 2010, 2013, 2007, 2009, 1989, 2019, 2004, 2003,
#        2017, 2006, 2020, 2005, 1999, 2002, 2014, 2012, 2015, 1995, 2000,
#        2018, 1991, 1972, 2001, 1998, 1997, 1990, 2021, 1992, 1996, 1988,
#        1987, 1985, 2022, 1981, 1993, 2023, 1953], dtype=int64)

# %%
#Distinct Fuel Type
car['Fuel type'].unique()
# Out:
# array(['Diesel', 'Petrol', 'Petrol Plug-in Hybrid', 'Petrol Hybrid',
#        'Electric', 'Diesel Hybrid'], dtype=object)

# %%
#Distinct Body Type
car['Body type'].unique()
# Out:
# array(['Hatchback', 'Coupe', 'Estate', 'Saloon', 'Convertible', 'MPV',
#        'SUV', 'Minibus', 'Combi Van', 'Pickup'], dtype=object)

# %%
#Distinct Engine
car['Engine'].unique()
# Out:
# array(['1.4L', '1.2L', '1.3L', '2.0L', '1.6L', '2.3L', '1.8L', '1.0L',
#        '3.0L', '1.5L', '1.9L', '2.4L', '2.2L', '3.5L', '3.2L', '2.5L',
#        '1.1L', '3.1L', '3.7L', '2.6L', '2.1L', '2.8L', '5.0L', '0.8L',
#        '2.7L', '1.7L', '0.9L', '4.2L', nan, '4.4L', '4.3L', '3.3L',
#        '5.5L', '4.8L', '6.3L'], dtype=object)

# %%
#Distinct GearBox
car['Gearbox'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
#Distinct Emission Class
car['Emission Class'].unique()
# Out:
# array(['Euro 6', 'Euro 4', 'Euro 5', nan, 'Euro 3', 'Euro 2', 'Euro 1'],
#       dtype=object)

# %%
#Display all records with Fuel Type of Diesel.
#How many are they?
car.loc[car['Fuel type'] == 'Diesel'].count()
# Out:
# Unnamed: 0           1218
# title                1218
# Price                1218
# Mileage(miles)       1218
# Registration_Year    1218
# Previous Owners       812
# Fuel type            1218
# Body type            1218
# Engine               1213
# Gearbox              1218
# Doors                1212
# Seats                1210
# Emission Class       1207
# Service history       175
# dtype: int64

# %%
#Display all records with Fuel Type of Petrol.
#How many are they?
car.loc[car['Fuel type'] =='Petrol'].count()
# Out:
# Unnamed: 0           2361
# title                2361
# Price                2361
# Mileage(miles)       2361
# Registration_Year    2361
# Previous Owners      1397
# Fuel type            2361
# Body type            2361
# Engine               2354
# Gearbox              2361
# Doors                2345
# Seats                2335
# Emission Class       2322
# Service history       361
# dtype: int64

# %%
#Display all records with Fuel Type of "Petrol Plug-in Hybrid".
#How many are they?
car.loc[car['Fuel type'] =='Petrol Plug-in Hybrid'].count()
# Out:
# Unnamed: 0           27
# title                27
# Price                27
# Mileage(miles)       27
# Registration_Year    27
# Previous Owners      25
# Fuel type            27
# Body type            27
# Engine               26
# Gearbox              27
# Doors                27
# Seats                27
# Emission Class       27
# Service history       0
# dtype: int64

# %%
#How many records do we have in each "Body Type" category?
#Extract all the records in each "body type" category and put them in a new csv file
car['Body type'].value_counts()
# Out:
# Hatchback      2279
# SUV             460
# Saloon          368
# Estate          171
# MPV             153
# Coupe           139
# Convertible     109
# Pickup            3
# Combi Van         2
# Minibus           1
# Name: Body type, dtype: int64

# %%
#Saving Body Type in a new csv File
car.to_csv('Body type.csv',index=False)

# %%
#How many records do we have in each "Doors" category?
#Extract all the records in each "Doors" category and put them in a new csv file
car['Doors'].value_counts()
# Out:
# 5.0    2342
# 3.0     735
# 4.0     367
# 2.0     216
# Name: Doors, dtype: int64

# %%
#Saving Doors in a new csv File
car.to_csv('Doors.csv', index=False)

# %%
#How many records do we have in each "Registration_Year" category?
car['Registration_Year'].value_counts()
# Out:
# 2011    289
# 2014    287
# 2012    275
# 2010    271
# 2009    251
# 2007    246
# 2016    245
# 2013    242
# 2008    226
# 2019    211
# 2015    210
# 2017    164
# 2006    149
# 2020    106
# 2005    104
# 2018     95
# 2021     85
# 2004     72
# 2003     53
# 2002     30
# 2001     25
# 2022      8
# 2023      6
# 1999      5
# 2000      4
# 1997      3
# 1990      3
# 1995      3
# 1998      3
# 1988      2
# 1987      2
# 1991      2
# 1972      1
# 1992      1
# 1996      1
# 1985      1
# 1981      1
# 1993      1
# 1989      1
# 1953      1
# Name: Registration_Year, dtype: int64

# %%
#How many records do we have in each "Gearbox" category?
car['Gearbox'].value_counts()
# Out:
# Manual       2868
# Automatic     817
# Name: Gearbox, dtype: int64

# %%
#How many records do we have in each "Engine" category?
car['Engine'].value_counts()
# Out:
# 1.6L    734
# 2.0L    553
# 1.2L    521
# 1.4L    421
# 1.0L    326
# 1.5L    294
# 1.3L    170
# 1.8L    158
# 3.0L     79
# 2.2L     75
# 2.1L     63
# 1.1L     39
# 1.7L     35
# 2.5L     33
# 1.9L     31
# 2.4L     28
# 0.9L     15
# 2.7L     11
# 3.5L     10
# 3.2L      7
# 3.7L      5
# 4.4L      5
# 2.3L      4
# 2.6L      4
# 4.2L      4
# 5.0L      3
# 2.8L      3
# 0.8L      2
# 4.3L      2
# 5.5L      1
# 4.8L      1
# 3.1L      1
# 3.3L      1
# 6.3L      1
# Name: Engine, dtype: int64

# %%
from matplotlib import pyplot as pt

# %%
ax = car.Registration_Year.value_counts().plot(kind="bar", figsize=(10,6))
ax.set_xlabel("Registration Year")
ax.set_ylabel("User")
ax.set_title('Graph showing Registration Year of Used_Car')
# Out:
# Text(0.5, 1.0, 'Graph showing Registration Year of Used_Car')

# %%
pt.pie(car['Registration_Year'].value_counts(), labels =car['Registration_Year'].unique(), autopct="%0.1f%%", radius=3)
pt.title("Graph showing Registration Year of Used_Car")
pt.show()

# %%
ax = car['Fuel type'].value_counts().plot(kind="bar", figsize=(10,6))
ax.set_xlabel("Fuel type")
ax.set_ylabel("Number of User")
ax.set_title("Graph showing Fuel Type of Used_Car")
# Out:
# Text(0.5, 1.0, 'Graph showing Fuel Type of Used_Car')

# %%
explode = (0.01, 0.01, 1, 1, 1, 2)
pt.pie(car['Fuel type'].value_counts(),explode=explode, labels =car['Fuel type'].unique(), autopct="%0.1f%%")
pt.title("Graph showing Fuel Type of Used_Car")
pt.show()

# %%
ax = car['Body type'].value_counts().plot(kind="bar", figsize=(10,6))
ax.set_xlabel("Body type")
ax.set_ylabel("Number of User")
ax.set_title("Graph Showing Body Type of Used_Car")
# Out:
# Text(0.5, 1.0, 'Graph Showing Body Type of Used_Car')

# %%
explode = (0.01, 0.01, 0.01, 0.01, 0.01, 0.02, 0.02, 0.5, 2, 4)
pt.pie(car['Body type'].value_counts(), labels =car['Body type'].unique(), explode=explode, autopct="%0.1f%%", radius=1.1)
pt.title("Graph Showing Body Type of Used_Car")
pt.show()

# %%
ax = car['Engine'].value_counts().plot(kind="bar", figsize=(10,6))
ax.set_xlabel("Engine")
ax.set_ylabel("Number of User")
ax.set_title("Graph Showing Engine of Used_Car")
# Out:
# Text(0.5, 1.0, 'Graph Showing Engine of Used_Car')

# %%
ax = car['Doors'].value_counts().plot(kind="bar", figsize=(10,6))
ax.set_xlabel("Doors")
ax.set_ylabel("Number of User")
ax.set_title("Graph Showing Doors of Used_Car")
# Out:
# Text(0.5, 1.0, 'Graph Showing Doors of Used_Car')

# %%
ax = car['Seats'].value_counts().plot(kind="bar", figsize=(10,6))
ax.set_xlabel("Seats")
ax.set_ylabel("Number of User")
ax.set_title("Graph Showing Seat")
